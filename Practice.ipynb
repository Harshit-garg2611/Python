# %%
x = [10,20,30]
y=x
print(id(x),";", id(y))

y[1]=25
print(y)
print(x)


x.append(35)
print(x)
print(y)
# Out:
# 2035539242432 ; 2035539242432
# [10, 25, 30]
# [10, 25, 30]
# [10, 25, 30, 35]
# [10, 25, 30, 35]

# %%
L = ["Zebra", "Monkey", 2, 3, True]

for index,element in enumerate(L):
    print(element,index,type(element))
# Out:
# Zebra 0 <class 'str'>
# Monkey 1 <class 'str'>
# 2 2 <class 'int'>
# 3 3 <class 'int'>
# True 4 <class 'bool'>

# %%
U = [2,3,True,"Zebra","Monkey"]
print(L==U)
# Out:
# False

# %%
n = [10,20,["I","WE","US"]]
print(n)
print(n[0])
print(n[2])
print(n[2][2])
# Out:
# [10, 20, ['I', 'WE', 'US']]
# 10
# ['I', 'WE', 'US']
# US

# %%
print(type(10))
print(type((10)))
print(type((10,20)))

a=10,
print(type(a))


print(type(()))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
s = {10,20,30}
s1 = s.copy()
print(id(s), id(s1))
# Out:
# 2035539940672 2035539045824

# %%
print(s.clear())
print(s)
# Out:
# None
# set()

# %%
i,j=1,1

for i in range(1,11):
    if(i%3!=0):
        j+=2
        continue
    if(j%3==0):
        break
print(i+j)
# Out:
# 15

# %%
l = eval(input("Enter list"))
s = list(set(l))
print(s)
# Out:
# [0, 1, 2, 3, 4, 5, 7]

# %%
d = {101:"Harshit", 102:"Mohit"}

print(d.get(102))
# Out:
# Mohit

# %%
d.get(101)
# Out:
# 'Harshit'

# %%
d.get(103,"Mehak")
# Out:
# 'Mehak'

# %%
print(d)
# Out:
# {101: 'Harshit', 102: 'Mohit'}

# %%
d.setdefault(104,"Mehak")
# Out:
# 'Mehak'

# %%
print(d)
# Out:
# {101: 'Harshit', 102: 'Mohit', 104: 'Mehak'}

# %%
def sum():
    a = eval(input("numer1: "))
    b = eval(input("numer2: "))
    return a+b


print(sum())
# Out:
# 13

# %%
def fact(n):
    if(n==0 | n==1):
        return 1
        
    return n*fact(n-1)

# %%
fact(5)
# Out:
# 120

# %%
x = 5
print(x)
y = x
print(x)
print(y)
x = x+2
print(x)
x+= x+4
print(x)
# Out:
# 5
# 5
# 5
# 7
# 18

# %%
name = "Harshit"
print(name or "Lion")
print(name and "Lion")
print("Lion" or name)
print("Lion" and name)
# Out:
# Harshit
# Lion
# Lion
# Harshit
